# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## SEIR

# %%
fj_seir = pd.read_csv('data/fj/fj_simple_seir.csv')
fp_seir = pd.read_csv('data/fp/fp_simple_seir.csv')
ws_seir = pd.read_csv('data/ws/ws_simple_seir.csv')
fj_seir['Day'] = fj_seir['Day'] + 1
fp_seir['Day'] = fp_seir['Day'] + 1
ws_seir['Day'] = ws_seir['Day'] + 1

# %% [markdown]
# ## TN-SEIR

# %%
fj_tNet = pd.read_csv('data/fj/fj_no_measure.csv')
fp_tNet = pd.read_csv('data/fp/fp_no_measure.csv')
ws_tNet = pd.read_csv('data/ws/ws_no_measure.csv')

# %% [markdown]
# ## SEIR vs. TN-SEIR

# %%
plt.figure(figsize=(12, 4))

# Plot Fiji
plt.subplot(1, 3, 1)
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fj_tNet['Day'] / 7, fj_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('FJ', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot French Polynesia
plt.subplot(1, 3, 2)
plt.plot(fp_seir['Day'] / 7, fp_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fp_tNet['Day'] / 7, fp_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('FP', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(1, 3, 3)
plt.plot(ws_seir['Day'] / 7, ws_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(ws_tNet['Day'] / 7, ws_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('WS', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

lines, labels = plt.subplot(1, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=3, fontsize=10)
# Adjust layout and save figure
plt.tight_layout(rect=[0, 0.05, 1, 0.96])
plt.savefig('three_countries_seir_tn-seir.png', dpi=400)
plt.show()

# %% [markdown]
# ## Lockdown

# %%
# No Measure
fj_no_measure = pd.read_csv('data/fj/fj_no_measure.csv')
fp_no_measure = pd.read_csv('data/fp/fp_no_measure.csv')
ws_no_measure = pd.read_csv('data/ws/ws_no_measure.csv')

# %% [markdown]
# ### Fiji

# %%
# Fiji Lockdown
fj_outside = pd.read_csv('data/fj/fj_lockdown_outsideworld.csv')
fj_city = pd.read_csv('data/fj/fj_lockdown_outside_suva.csv')
fj_connection = pd.read_csv('data/fj/fj_lockdownd_suva_nadi.csv')
fj_all = pd.read_csv('data/fj/fj_lockdown_all.csv')

# %%
# Highlight the intervention period
method_start = 30
method_end = 130

# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_outside['Day'], fj_outside['S'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fj_city['Day'], fj_city['S'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fj_connection['Day'], fj_connection['S'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fj_all['Day'], fj_all['S'] / 1000, label='All Locations', marker='s', markevery=30)

plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_outside['Day'], fj_outside['E'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fj_city['Day'], fj_city['E'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fj_connection['Day'], fj_connection['E'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fj_all['Day'], fj_all['E'] / 1000, label='All Locations', marker='s', markevery=30)
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_outside['Day'], fj_outside['I'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fj_city['Day'], fj_city['I'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fj_connection['Day'], fj_connection['I'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fj_all['Day'], fj_all['I'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_outside['Day'], fj_outside['R'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fj_city['Day'], fj_city['R'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fj_connection['Day'], fj_connection['R'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fj_all['Day'], fj_all['R'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.savefig('locckdown_fj.png', bbox_inches='tight', dpi=400)
plt.show()

# %% [markdown]
# ### French Polynesia

# %%
# French Polynesia Lockdown
fp_outside = pd.read_csv('data/fp/fp_lockdown_outsideworld.csv')
fp_city = pd.read_csv('data/fp/fp_lockdown_outside_tahiti.csv')
fp_connection = pd.read_csv('data/fp/fp_lockdownd_tahiti_borabora.csv')
fp_all = pd.read_csv('data/fp/fp_lockdown_all.csv')

# %%
# Highlight the intervention period
method_start = 30
method_end = 130

# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fp_outside['Day'], fp_outside['S'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fp_city['Day'], fp_city['S'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fp_connection['Day'], fp_connection['S'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fp_all['Day'], fp_all['S'] / 1000, label='All Locations', marker='s', markevery=30)

plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fp_outside['Day'], fp_outside['E'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fp_city['Day'], fp_city['E'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fp_connection['Day'], fp_connection['E'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fp_all['Day'], fp_all['E'] / 1000, label='All Locations', marker='s', markevery=30)
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fp_outside['Day'], fp_outside['I'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fp_city['Day'], fp_city['I'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fp_connection['Day'], fp_connection['I'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fp_all['Day'], fp_all['I'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fp_outside['Day'], fp_outside['R'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(fp_city['Day'], fp_city['R'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(fp_connection['Day'], fp_connection['R'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(fp_all['Day'], fp_all['R'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.savefig('locckdown_fp.png', bbox_inches='tight', dpi=400)
plt.show()

# %% [markdown]
# ### Samoa

# %%
# Samoa Lockdown
ws_outside = pd.read_csv('data/ws/ws_lockdown_outsideworld.csv')
ws_city = pd.read_csv('data/ws/ws_lockdown_outside_falealili.csv')
ws_connection = pd.read_csv('data/ws/ws_lockdownd_Faleata_Vaimauga_Sagaga.csv')
ws_all = pd.read_csv('data/ws/ws_lockdown_all.csv')

# %%
# Highlight the intervention period
method_start = 30
method_end = 130

# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(ws_outside['Day'], ws_outside['S'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(ws_city['Day'], ws_city['S'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(ws_connection['Day'], ws_connection['S'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(ws_all['Day'], ws_all['S'] / 1000, label='All Locations', marker='s', markevery=30)

plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(ws_outside['Day'], ws_outside['E'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(ws_city['Day'], ws_city['E'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(ws_connection['Day'], ws_connection['E'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(ws_all['Day'], ws_all['E'] / 1000, label='All Locations', marker='s', markevery=30)
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(ws_outside['Day'], ws_outside['I'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(ws_city['Day'], ws_city['I'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(ws_connection['Day'], ws_connection['I'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(ws_all['Day'], ws_all['I'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(ws_outside['Day'], ws_outside['R'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(ws_city['Day'], ws_city['R'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(ws_connection['Day'], ws_connection['R'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(ws_all['Day'], ws_all['R'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.savefig('locckdown_ws.png', bbox_inches='tight', dpi=400)
plt.show()

# %% [markdown]
# ## Three Countries Comparison

# %%
plt.figure(figsize=(18, 20))


no_intervention_color = 'r'  # Red
intervention_color = 'b'  # Blue
no_intervention_marker = 'x'
intervention_marker = 'o'
shade_color = 'grey'
shade_alpha = 0.5
method_start = 5
method_end = 19

# Lockdown Outside World
# Plot Fiji
plt.subplot(4, 3, 1)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_outside['Day'] / 7, fj_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown Outside', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 2)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_outside['Day'] / 7, fp_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 3)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_outside['Day'] / 7, ws_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown Main City
# Plot Fiji
plt.subplot(4, 3, 4)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_city['Day'] / 7, fj_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown City of Port', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 5)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_city['Day'] / 7, fp_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 6)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_city['Day'] / 7, ws_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown Most Connections
# Plot Fiji
plt.subplot(4, 3, 7)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_connection['Day'] / 7, fj_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown Top Daily Mobility ', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 8)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_connection['Day'] / 7, fp_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 9)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_connection['Day'] / 7, ws_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown All
# Plot Fiji
plt.subplot(4, 3, 10)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_all['Day'] / 7, fj_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown All Locations', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 11)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_all['Day'] / 7, fp_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 12)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_all['Day'] / 7, ws_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Number of Cases (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)


lines, labels = plt.subplot(4, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='upper center', ncol=3, fontsize=10)

plt.tight_layout(rect=[0, 0.01, 1, 0.96])
plt.savefig('locckdown_intervention_50.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
import matplotlib.patches as patches


def add_highlight_border(ax, color='green', linewidth=4):
    rect = patches.Rectangle(
        (0, 0), 1, 1, transform=ax.transAxes,  # 以坐标轴为参考
        fill=False, edgecolor=color, linewidth=linewidth
    )
    ax.add_patch(rect)


plt.figure(figsize=(18, 20))


no_intervention_color = 'r'  # Red
intervention_color = 'b'  # Blue
no_intervention_marker = 'x'
intervention_marker = 'o'
shade_color = 'grey'
shade_alpha = 0.5
method_start = 5
method_end = 19

#Hight Light
highlight_subplots = [1, 6, 11]

# Lockdown Outside World
# Plot Fiji
ax1 = plt.subplot(4, 3, 1)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_outside['Day'] / 7, fj_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown Outside World', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 2)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_outside['Day'] / 7, fp_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 3)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_outside['Day'] / 7, ws_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown Main City
# Plot Fiji
plt.subplot(4, 3, 4)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_city['Day'] / 7, fj_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown Port Cities', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 5)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_city['Day'] / 7, fp_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
ax2 = plt.subplot(4, 3, 6)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_city['Day'] / 7, ws_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown Most Connections
# Plot Fiji
plt.subplot(4, 3, 7)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_connection['Day'] / 7, fj_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown Major Travel Routes', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(4, 3, 8)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_connection['Day'] / 7, fp_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 9)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_connection['Day'] / 7, ws_connection['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Lockdown All
# Plot Fiji
plt.subplot(4, 3, 10)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_all['Day'] / 7, fj_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Nationwide Lockdown', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
ax3 = plt.subplot(4, 3, 11)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_all['Day'] / 7, fp_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(4, 3, 12)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_all['Day'] / 7, ws_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=22, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)


lines, labels = plt.subplot(4, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='upper center', ncol=3, fontsize=14)

add_highlight_border(ax1, color='#32CD32', linewidth=14)
add_highlight_border(ax2, color='#32CD32', linewidth=14)
add_highlight_border(ax3, color='#32CD32', linewidth=14)
plt.tight_layout(rect=[0, 0.01, 1, 0.96])
plt.savefig('locckdown_intervention_iso.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
# Fiji Lockdown Outside

fj_outside = pd.read_csv('data/fj/fj_lockdown_outsideworld.csv')
fj_bigcity = pd.read_csv('data/fj/locations/fj_outsideworld_Suva.csv')
fj_smallcity = pd.read_csv('data/fj/locations/fj_outsideworld_Malolo(Matamanoa Island).csv')

# French Polynesia Lockdown All Locations

fp_all = pd.read_csv('data/fp/fp_lockdown_all.csv')
fp_bigcity = pd.read_csv('data/fp/locations/fp_lockdownd_all_Tahiti.csv')
fp_smallcity = pd.read_csv('data/fp/locations/fp_lockdownd_all_Ahe.csv')

# Samoa Lockdown City of Port

ws_city = pd.read_csv('data/ws/ws_lockdown_outside_falealili.csv')
ws_bigcity = pd.read_csv('data/ws/locations/ws_lockdown_cityofport_Falealili.csv')
ws_smallcity = pd.read_csv('data/ws/locations/ws_lockdown_cityofport_Vaa o Fonoti.csv')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

plt.figure(figsize=(16, 6))

intervention_color = 'b'  # Blue
big_city = 'g'  # Green
small_city = 'y'  # Yellow
intervention_marker = 'o'
big_city_marker = 'x'
small_city_marker = '*'
shade_color = 'grey'
shade_alpha = 0.5
method_start = 5
method_end = 19

# Lockdown Outside World
# Plot Fiji
ax1 = plt.subplot(1, 3, 1)
ax1.plot(fj_outside['Day'] / 7, fj_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax1.plot(fj_bigcity['Day'] / 7, fj_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax1.plot(fj_smallcity['Day'] / 7, fj_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax1.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax1.set_xlabel('EpiWeek')
ax1.set_ylabel('Infectious (thousand)')
ax1.set_title('FJ - Outside World', fontsize=14, fontweight='bold')
ax1.legend(fontsize=10).set_visible(False)

# Lockdown All
# Plot French Polynesia
ax2 = plt.subplot(1, 3, 2)
ax2.plot(fp_all['Day'] / 7, fp_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax2.plot(fp_bigcity['Day'] / 7, fp_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax2.plot(fp_smallcity['Day'] / 7, fp_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax2.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax2.set_xlabel('EpiWeek')
ax2.set_ylabel('Infectious (thousand)')
ax2.set_title('FP - All', fontsize=14, fontweight='bold')
ax2.legend(fontsize=10).set_visible(False)

# Lockdown City of Port
# Plot Samoa
ax3 = plt.subplot(1, 3, 3)
ax3.plot(ws_city['Day'] / 7, ws_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax3.plot(ws_bigcity['Day'] / 7, ws_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax3.plot(ws_smallcity['Day'] / 7, ws_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax3.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax3.set_xlabel('EpiWeek')
ax3.set_ylabel('Infectious (thousand)')
ax3.set_title('SW - City of Port', fontsize=14, fontweight='bold')
ax3.legend(fontsize=10).set_visible(False)


lines, labels = ax1.get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=4, fontsize=10)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.savefig('lockdown_cities.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

plt.figure(figsize=(16, 6))

intervention_color = 'b'  # Blue
big_city = 'g'  # Green
small_city = 'y'  # Yellow
intervention_marker = 'o'
big_city_marker = 'x'
small_city_marker = '*'
shade_color = 'grey'
shade_alpha = 0.5
method_start = 5
method_end = 19

# Lockdown Outside World
# Plot Fiji
ax1 = plt.subplot(1, 3, 1)
ax1.plot(fj_outside['Day'] / 7, fj_outside['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax1.plot(fj_bigcity['Day'] / 7, fj_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax1.plot(fj_smallcity['Day'] / 7, fj_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax1.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax1.set_xlabel('EpiWeek')
ax1.set_ylabel('Number of Cases (thousand)')
ax1.set_title('Fiji', fontsize=20, fontweight='bold')
ax1.text(0.5, -0.25, 'Outside World', fontsize=20, ha='center', transform=ax1.transAxes)
ax1.legend(fontsize=10).set_visible(False)

# Lockdown All
# Plot French Polynesia
ax2 = plt.subplot(1, 3, 2)
ax2.plot(fp_all['Day'] / 7, fp_all['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax2.plot(fp_bigcity['Day'] / 7, fp_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax2.plot(fp_smallcity['Day'] / 7, fp_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax2.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax2.set_xlabel('EpiWeek')
ax2.set_ylabel('Number of Cases (thousand)')
ax2.set_title('French Polynesia', fontsize=20, fontweight='bold')
ax2.text(0.5, -0.25, 'Nationwide', fontsize=20, ha='center', transform=ax2.transAxes)
ax2.legend(fontsize=10).set_visible(False)

# Lockdown City of Port
# Plot Samoa
ax3 = plt.subplot(1, 3, 3)
ax3.plot(ws_city['Day'] / 7, ws_city['I'] / 1000, marker=intervention_marker, markevery=30, label='Nation', color=intervention_color)
ax3.plot(ws_bigcity['Day'] / 7, ws_bigcity['I'] / 1000, marker=big_city_marker, markevery=30, label='Urban', color=big_city)
ax3.plot(ws_smallcity['Day'] / 7, ws_smallcity['I'] / 1000, marker=small_city_marker, markevery=30, label='Rural', color=small_city)
ax3.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
ax3.set_xlabel('EpiWeek')
ax3.set_ylabel('Number of Cases (thousand)')
ax3.set_title('Samoa', fontsize=20, fontweight='bold')
ax3.text(0.5, -0.25, 'Port Cities', fontsize=20, ha='center', transform=ax3.transAxes)
ax3.legend(fontsize=10).set_visible(False)

lines, labels = ax1.get_legend_handles_labels()
plt.figlegend(lines, labels, loc='upper center', ncol=4, fontsize=12)

plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.savefig('lockdown_areas.png', bbox_inches='tight', dpi=400)
plt.show()
