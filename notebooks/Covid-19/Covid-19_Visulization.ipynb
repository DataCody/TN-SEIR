# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fj_seir = pd.read_csv('data/fj/fj_simple_seir.csv')
fp_seir = pd.read_csv('data/fp/fp_simple_seir.csv')
ws_seir = pd.read_csv('data/ws/ws_simple_seir.csv')
fj_seir['Day'] = fj_seir['Day'] + 1
fp_seir['Day'] = fp_seir['Day'] + 1
ws_seir['Day'] = ws_seir['Day'] + 1

# %%
fj_tNet = pd.read_csv('data/fj/fj_no_measure.csv')
fp_tNet = pd.read_csv('data/fp/fp_no_measure.csv')
ws_tNet = pd.read_csv('data/ws/ws_no_measure.csv')

# %%
plt.figure(figsize=(14, 10))

#plt.suptitle('SEIR Model Comparison', fontsize=16)

# Plot S
plt.subplot(3, 4, 1)
plt.plot(fj_seir['Day'] / 7, fj_seir['S'] / 1000, label='SEIR', marker='o', markevery=30)
plt.plot(fj_tNet['Day'] / 7, fj_tNet['S'] / 1000, label='TN-SEIR', marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Susceptible (thousand)')
#plt.title('Susceptible')
plt.legend(fontsize=8).set_visible(False)
plt.text(-0.1, 1.1, 'Fiji', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot E
plt.subplot(3, 4, 2)
plt.plot(fj_seir['Day'] / 7, fj_seir['E'] / 1000, marker='o', markevery=30)
plt.plot(fj_tNet['Day'] / 7, fj_tNet['E'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Exposed (thousand)')
plt.legend(fontsize=8)

# Plot I
plt.subplot(3, 4, 3)
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30)
plt.plot(fj_tNet['Day'] / 7, fj_tNet['I'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.legend(fontsize=8)

# Plot R
plt.subplot(3, 4, 4)
plt.plot(fj_seir['Day'] / 7, fj_seir['R'] / 1000, marker='o', markevery=30)
plt.plot(fj_tNet['Day'] / 7, fj_tNet['R'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Recovered (thousand)')
plt.legend(fontsize=8)

# Plot S
plt.subplot(3, 4, 5)
plt.plot(fp_seir['Day'] / 7, fp_seir['S'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['S'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Susceptible (thousand)')
plt.legend(fontsize=8)
plt.text(-0.1, 1.1, 'French Polynesia', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot E
plt.subplot(3, 4, 6)
plt.plot(fp_seir['Day'] / 7, fp_seir['E'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['E'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Exposed (thousand)')

plt.legend(fontsize=8)

# Plot I
plt.subplot(3, 4, 7)
plt.plot(fp_seir['Day'] / 7, fp_seir['I'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['I'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')

plt.legend(fontsize=8)

# Plot R
plt.subplot(3, 4, 8)
plt.plot(fp_seir['Day'] / 7, fp_seir['R'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['R'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Recovered (thousand)')
plt.legend(fontsize=8)


# Plot S
plt.subplot(3, 4, 9)
plt.plot(ws_seir['Day'] / 7, ws_seir['S'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['S'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Susceptible (thousand)')
plt.legend(fontsize=8)
plt.text(-0.1, 1.1, 'Samoa', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot E
plt.subplot(3, 4, 10)
plt.plot(ws_seir['Day'] / 7, ws_seir['E'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['E'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Exposed (thousand)')

plt.legend(fontsize=8)

# Plot I
plt.subplot(3, 4, 11)
plt.plot(ws_seir['Day'] / 7, ws_seir['I'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['I'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')

plt.legend(fontsize=8)

# Plot R
plt.subplot(3, 4, 12)
plt.plot(ws_seir['Day'] / 7, ws_seir['R'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['R'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Recovered (thousand)')
plt.legend(fontsize=8)

lines, labels = plt.subplot(3, 4, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='upper center', ncol=2, fontsize=10)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('seir_model_comparison.png', dpi=300)
plt.show()
# Out:
# /var/folders/6b/kz_zdjy5609583gv1q69hvcm0000gn/T/ipykernel_94932/2624133597.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=8)
# /var/folders/6b/kz_zdjy5609583gv1q69hvcm0000gn/T/ipykernel_94932/2624133597.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=8)
# /var/folders/6b/kz_zdjy5609583gv1q69hvcm0000gn/T/ipykernel_94932/2624133597.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=8)
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot Fiji
plt.subplot(1, 3, 1)
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fj_tNet['Day'] / 7, fj_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot French Polynesia
plt.subplot(1, 3, 2)
plt.plot(fp_seir['Day'] / 7, fp_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fp_tNet['Day'] / 7, fp_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(1, 3, 3)
plt.plot(ws_seir['Day'] / 7, ws_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(ws_tNet['Day'] / 7, ws_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

lines, labels = plt.subplot(1, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=3, fontsize=10)
# Adjust layout and save figure
plt.tight_layout(rect=[0, 0.05, 1, 0.96])
plt.savefig('three_countries_seir_tn-seir.png', dpi=300)
plt.show()

# %% [markdown]
# ## Infectious Comparison

# %%
# No Measure
fj_no_measure = pd.read_csv('data/fj/fj_no_measure.csv')
fp_no_measure = pd.read_csv('data/fp/fp_no_measure.csv')
ws_no_measure = pd.read_csv('data/ws/ws_no_measure.csv')

# Lockdown
fj_lockdownd = pd.read_csv('data/fj/fj_lockdownd_suva_nadi.csv')
fp_lockdownd = pd.read_csv('data/fp/fp_lockdownd_tahiti_borabora.csv')
ws_lockdownd = pd.read_csv('data/ws/ws_lockdownd_Faleata_Vaimauga_Sagaga.csv')

# Facemask
fj_mask = pd.read_csv('data/fj/fj_mask_surgical.csv')
fp_mask = pd.read_csv('data/fp/fp_mask_surgical.csv')
ws_mask = pd.read_csv('data/ws/ws_mask_surgical.csv')

# Social Distance
fj_social_1m = pd.read_csv('data/fj/fj_social_1m.csv')
fp_social_1m = pd.read_csv('data/fp/fp_social_1m.csv')
ws_social_1m = pd.read_csv('data/ws/ws_social_1m.csv')

# Remote working
fj_wfh_50 = pd.read_csv('data/fj/fj_wfh_50.csv')
fp_wfh_50 = pd.read_csv('data/fp/fp_wfh_50.csv')
ws_wfh_50 = pd.read_csv('data/ws/ws_wfh_50.csv')

# Vaccine
fj_vaccine = pd.read_csv('data/fj/fj_vaccine_001rate.csv')
fp_vaccine = pd.read_csv('data/fp/fp_vaccine_001rate.csv')
ws_vaccine = pd.read_csv('data/ws/ws_vaccine_001rate.csv')

# %%
plt.figure(figsize=(18, 20))

## Lockdown
# Plot Fiji
plt.subplot(5, 3, 1)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_lockdownd['Day'] / 7, fj_lockdownd['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
#plt.text(-0.1, 1.1, 'Lockdown', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='top')
plt.text(-0.2, 0.5, 'Lockdown', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 2)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fp_lockdownd['Day'] / 7, fp_lockdownd['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 3)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(ws_lockdownd['Day'] / 7, ws_lockdownd['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

## Facemask
# Plot Fiji
plt.subplot(5, 3, 4)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_mask['Day'] / 7, fj_mask['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
#plt.text(-0.1, 1.1, 'Facemask', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='top')
plt.text(-0.2, 0.5, 'Facemask', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 5)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fp_mask['Day'] / 7, fp_mask['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 6)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(ws_mask['Day'] / 7, ws_mask['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

## Social Distance
# Plot Fiji
plt.subplot(5, 3, 7)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_social_1m['Day'] / 7, fj_social_1m['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
#plt.text(-0.1, 1.1, 'Social Distance', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='top')
plt.text(-0.2, 0.5, 'Social Distance', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 8)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fp_social_1m['Day'] / 7, fp_social_1m['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 9)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(ws_social_1m['Day'] / 7, ws_social_1m['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

## Remote Working
# Plot Fiji
plt.subplot(5, 3, 10)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_wfh_50['Day'] / 7, fj_wfh_50['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
#plt.text(-0.1, 1.1, 'Remote Working', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='top')
plt.text(-0.2, 0.5, 'Remote Working', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 11)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fp_wfh_50['Day'] / 7, fp_wfh_50['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 12)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(ws_wfh_50['Day'] / 7, ws_wfh_50['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

## Vaccine
# Plot Fiji
plt.subplot(5, 3, 13)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_vaccine['Day'] / 7, fj_vaccine['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
#plt.text(-0.1, 1.1, 'Vaccine', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='top')
plt.text(-0.2, 0.5, 'Vaccine', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 14)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_vaccine['Day'] / 7, fj_vaccine['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 15)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_vaccine['Day'] / 7, fj_vaccine['I'] / 1000, marker='o', markevery=30, label='Intervention')
# Highlight the intervention period
method_start = 2
method_end = 15
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

lines, labels = plt.subplot(5, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=3, fontsize=10)

plt.tight_layout(rect=[0, 0.01, 1, 0.96])
plt.savefig('infectous_intervention.png', bbox_inches='tight', dpi=400)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 20))

# 定义颜色和形状
no_intervention_color = 'b'  # 蓝色
intervention_color = 'r'  # 红色
no_intervention_marker = 'x'
intervention_marker = 'o'
shade_color = 'grey'
shade_alpha = 0.5
method_start = 2
method_end = 15

# Lockdown
# Plot Fiji
plt.subplot(5, 3, 1)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_lockdownd['Day'] / 7, fj_lockdownd['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Lockdown', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 2)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_lockdownd['Day'] / 7, fp_lockdownd['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 3)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_lockdownd['Day'] / 7, ws_lockdownd['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Facemask
# Plot Fiji
plt.subplot(5, 3, 4)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_mask['Day'] / 7, fj_mask['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Facemask', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 5)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_mask['Day'] / 7, fp_mask['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 6)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_mask['Day'] / 7, ws_mask['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Social Distance
# Plot Fiji
plt.subplot(5, 3, 7)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_social_1m['Day'] / 7, fj_social_1m['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Social Distance', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 8)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_social_1m['Day'] / 7, fp_social_1m['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 9)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_social_1m['Day'] / 7, ws_social_1m['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Remote Working
# Plot Fiji
plt.subplot(5, 3, 10)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_wfh_50['Day'] / 7, fj_wfh_50['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Remote Working', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 11)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_wfh_50['Day'] / 7, fp_wfh_50['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 12)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_wfh_50['Day'] / 7, ws_wfh_50['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Vaccine
# Plot Fiji
plt.subplot(5, 3, 13)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fj_vaccine['Day'] / 7, fj_vaccine['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.2, 0.5, 'Vaccine', transform=plt.gca().transAxes, fontsize=16, fontweight='bold', va='center', rotation=90)

# Plot French Polynesia
plt.subplot(5, 3, 14)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(fp_vaccine['Day'] / 7, fp_vaccine['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(5, 3, 15)
plt.plot(ws_no_measure['Day'] / 7, ws_no_measure['I'] / 1000, marker=no_intervention_marker, markevery=30, label='No Intervention', color=no_intervention_color)
plt.plot(ws_vaccine['Day'] / 7, ws_vaccine['I'] / 1000, marker=intervention_marker, markevery=30, label='Intervention', color=intervention_color)
plt.axvspan(method_start, method_end, color=shade_color, alpha=shade_alpha, label='Intervention Period')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# 添加图例
lines, labels = plt.subplot(5, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=3, fontsize=10)

plt.tight_layout(rect=[0, 0.01, 1, 0.96])
plt.savefig('infectious_intervention.png', bbox_inches='tight', dpi=400)
plt.show()
