# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

markers = ['o', 'v', '^', '<', '>', 's', 'p', '*', 'h', 'H', 'D', 'd', '+', 'x', '|', '_']

plt.figure(figsize=(10, 6))

for i, marker in enumerate(markers):
    plt.plot(x, [value + i for value in y], label=f'marker {marker}', marker=marker)

plt.legend()
plt.show()

# %% [markdown]
# ### Simple SEIR vs. Travel Network SEIR

# %%
simple_seir = pd.read_csv('ws/ws_simple_seir.csv')
no_measure = pd.read_csv('ws/ws_no_measure.csv')

# %%
simple_seir['Day'] = simple_seir['Day'] + 1
print(simple_seir.head())
# Out:
#    Day              S          E          I         R     Total
# 0    1  304548.000000  30.000000   3.000000  0.000000  304581.0
# 1    2  304547.574061  25.771035   7.326214  0.328690  304581.0
# 2    3  304546.833495  22.482917  10.783413  0.900174  304581.0
# 3    4  304545.840928  19.933112  13.559834  1.666126  304581.0
# 4    5  304544.645412  17.962769  15.803125  2.588695  304581.0

# %%
pd.set_option('display.expand_frame_repr', False)
print(no_measure.head())
# Out:
#    Day  Population       S    E    I   R    S_ratio   E_ratio   I_ratio   R_ratio   Total
# 0    1      304579  304524   45   10   0  23.996030  0.003301  0.000670  0.000000  304579
# 1    2      304579  304455   93   29   2  23.990177  0.007301  0.002457  0.000064  304579
# 2    3      304579  304387  137   53   2  23.984372  0.011059  0.004500  0.000069  304579
# 3    4      304579  304327  155   89   8  23.979964  0.012105  0.007247  0.000683  304579
# 4    5      304579  304261  192  113  13  23.973855  0.015319  0.009688  0.001139  304579

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(simple_seir['Day'], simple_seir['S'] / 1000, label='Traditional SEIR', marker='o', markevery=30)
plt.plot(no_measure['Day'], no_measure['S'] / 1000, label='Travel Network SEIR', marker='x', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=8)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(simple_seir['Day'], simple_seir['E'] / 1000, label='Traditional SEIR', marker='o', markevery=30)
plt.plot(no_measure['Day'], no_measure['E'] / 1000, label='Travel Network SEIR', marker='x', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=8)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(simple_seir['Day'], simple_seir['I'] / 1000, label='Traditional SEIR', marker='o', markevery=30)
plt.plot(no_measure['Day'], no_measure['I'] / 1000, label='Travel Network SEIR', marker='x', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=8)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(simple_seir['Day'], simple_seir['R'] / 1000, label='Traditional SEIR', marker='o', markevery=30)
plt.plot(no_measure['Day'], no_measure['R'] / 1000, label='Travel Network SEIR', marker='x', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lockdown

# %%
lockdown_outsideworld = pd.read_csv('ws/ws_lockdown_outsideworld.csv')
lockdown_outside_tahiti = pd.read_csv('ws/ws_lockdown_outside_falealili.csv')
lockdownd_tahiti_borabora = pd.read_csv('ws/ws_lockdownd_Faleata_Vaimauga_Sagaga.csv')
lockdown_all = pd.read_csv('ws/ws_lockdown_all.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(lockdown_outsideworld['Day'], lockdown_outsideworld['S'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(lockdown_outside_tahiti['Day'], lockdown_outside_tahiti['S'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['S'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(lockdown_all['Day'], lockdown_all['S'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(lockdown_outsideworld['Day'], lockdown_outsideworld['E'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(lockdown_outside_tahiti['Day'], lockdown_outside_tahiti['E'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['E'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(lockdown_all['Day'], lockdown_all['E'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(lockdown_outsideworld['Day'], lockdown_outsideworld['I'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(lockdown_outside_tahiti['Day'], lockdown_outside_tahiti['I'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['I'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(lockdown_all['Day'], lockdown_all['I'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(lockdown_outsideworld['Day'], lockdown_outsideworld['R'] / 1000, label='Outside World', marker='o', markevery=30)
plt.plot(lockdown_outside_tahiti['Day'], lockdown_outside_tahiti['R'] / 1000, label='Largest Location', marker='x', markevery=30)
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['R'] / 1000, label='Popular Locations', marker='d', markevery=30)
plt.plot(lockdown_all['Day'], lockdown_all['R'] / 1000, label='All Locations', marker='s', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Facemask

# %%
mask_cloth = pd.read_csv('ws/ws_mask_cloth.csv')
mask_surgical = pd.read_csv('ws/ws_mask_surgical.csv')
mask_N95 = pd.read_csv('ws/ws_mask_N95.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(mask_cloth['Day'], mask_cloth['S'], label='Cloth Facemask', marker='o', markevery=10)
plt.plot(mask_surgical['Day'], mask_surgical['S'], label='Surgical Facemask', marker='x', markevery=10)
plt.plot(mask_N95['Day'], mask_N95['S'], label='N95 Facemask', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Susceptible')
plt.title('Facemask Susceptible Comparison')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(mask_cloth['Day'], mask_cloth['E'], label='Cloth Facemask', marker='o', markevery=10)
plt.plot(mask_surgical['Day'], mask_surgical['E'], label='Surgical Facemask', marker='x', markevery=10)
plt.plot(mask_N95['Day'], mask_N95['E'], label='N95 Facemask', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Exposed')
plt.title('Facemask Exposed Comparison')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(mask_cloth['Day'], mask_cloth['I'], label='Cloth Facemask', marker='o', markevery=10)
plt.plot(mask_surgical['Day'], mask_surgical['I'], label='Surgical Facemask', marker='x', markevery=10)
plt.plot(mask_N95['Day'], mask_N95['I'], label='N95 Facemask', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Infectious')
plt.title('Facemask Infectious Comparison')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(mask_cloth['Day'], mask_cloth['R'], label='Cloth Facemask', marker='o', markevery=10)
plt.plot(mask_surgical['Day'], mask_surgical['R'], label='Surgical Facemask', marker='x', markevery=10)
plt.plot(mask_N95['Day'], mask_N95['R'], label='N95 Facemask', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Recovered')
plt.title('Facemask Recovered Comparison')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Social Distance

# %%
social_1m = pd.read_csv('ws/ws_social_1m.csv')
social_2m = pd.read_csv('ws/ws_social_2m.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(social_1m['Day'], social_1m['S'], label='1-Meter Social Distance', marker='o', markevery=10)
plt.plot(social_2m['Day'], social_2m['S'], label='2-Meter Social Distance', marker='x', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Susceptible')
plt.title('Social Distance Susceptible Comparison')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(social_1m['Day'], social_1m['E'], label='1-Meter Social Distance', marker='o', markevery=10)
plt.plot(social_2m['Day'], social_2m['E'], label='2-Meter Social Distance', marker='x', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Exposed')
plt.title('Social Distance Susceptible Comparison')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(social_1m['Day'], social_1m['I'], label='1-Meter Social Distance', marker='o', markevery=10)
plt.plot(social_2m['Day'], social_2m['I'], label='2-Meter Social Distance', marker='x', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Infectious')
plt.title('Social Distance Susceptible Comparison')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(social_1m['Day'], social_1m['R'], label='1-Meter Social Distance', marker='o', markevery=10)
plt.plot(social_2m['Day'], social_2m['R'], label='2-Meter Social Distance', marker='x', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Recovered')
plt.title('Social Distance Susceptible Comparison')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Work From Home

# %%
wfh_20 = pd.read_csv('ws/ws_wfh_20.csv')
wfh_50 = pd.read_csv('ws/ws_wfh_50.csv')
wfh_80 = pd.read_csv('ws/ws_wfh_80.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(wfh_20['Day'], wfh_20['S'], label='20% WFH', marker='o', markevery=10)
plt.plot(wfh_50['Day'], wfh_50['S'], label='50% WFH', marker='x', markevery=10)
plt.plot(wfh_80['Day'], wfh_80['S'], label='80% WFH', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Susceptible')
plt.title('WFH Susceptible Comparison')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(wfh_20['Day'], wfh_20['E'], label='20% WFH', marker='o', markevery=10)
plt.plot(wfh_50['Day'], wfh_50['E'], label='50% WFH', marker='x', markevery=10)
plt.plot(wfh_80['Day'], wfh_80['E'], label='80% WFH', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Exposed')
plt.title('WFH Exposed Comparison')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(wfh_20['Day'], wfh_20['I'], label='20% WFH', marker='o', markevery=10)
plt.plot(wfh_50['Day'], wfh_50['I'], label='50% WFH', marker='x', markevery=10)
plt.plot(wfh_80['Day'], wfh_80['I'], label='80% WFH', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Infectious')
plt.title('WFH Infectious Comparison')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(wfh_20['Day'], wfh_20['R'], label='20% WFH', marker='o', markevery=10)
plt.plot(wfh_50['Day'], wfh_50['R'], label='50% WFH', marker='x', markevery=10)
plt.plot(wfh_80['Day'], wfh_80['R'], label='80% WFH', marker='d', markevery=10)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Recovered')
plt.title('WFH Recovered Comparison')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### All Measures Comparison in Same Country

# %%
vaccine = pd.read_csv('ws/ws_vaccine_001rate.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(no_measure['Day'], no_measure['S'] / 1000, label='No Intervention')
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['S'] / 1000, label='Lockdown')
plt.plot(mask_surgical['Day'], mask_surgical['S'] / 1000, label='Facemask')
plt.plot(social_1m['Day'], social_1m['S'] / 1000, label='Social Distance')
plt.plot(wfh_50['Day'], wfh_50['S'] / 1000, label='Work From Home')
plt.plot(vaccine['Day'], vaccine['S'] / 1000, label='Vaccine')
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(no_measure['Day'], no_measure['E'] / 1000, label='No Intervention')
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['E'] / 1000, label='Lockdown')
plt.plot(mask_surgical['Day'], mask_surgical['E'] / 1000, label='Facemask')
plt.plot(social_1m['Day'], social_1m['E'] / 1000, label='Social Distance')
plt.plot(wfh_50['Day'], wfh_50['E'] / 1000, label='Work From Home')
plt.plot(vaccine['Day'], vaccine['E'] / 1000, label='Vaccine')
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(no_measure['Day'], no_measure['I'] / 1000, label='No Intervention')
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['I'] / 1000, label='Lockdown')
plt.plot(mask_surgical['Day'], mask_surgical['I'] / 1000, label='Facemask')
plt.plot(social_1m['Day'], social_1m['I'] / 1000, label='Social Distance')
plt.plot(wfh_50['Day'], wfh_50['I'] / 1000, label='Work From Home')
plt.plot(vaccine['Day'], vaccine['I'] / 1000, label='Vaccine')
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(no_measure['Day'], no_measure['R'] / 1000, label='No Intervention')
plt.plot(lockdownd_tahiti_borabora['Day'], lockdownd_tahiti_borabora['R'] / 1000, label='Lockdown')
plt.plot(mask_surgical['Day'], mask_surgical['R'] / 1000, label='Facemask')
plt.plot(social_1m['Day'], social_1m['R'] / 1000, label='Social Distance')
plt.plot(wfh_50['Day'], wfh_50['R'] / 1000, label='Work From Home')
plt.plot(vaccine['Day'], vaccine['R'] / 1000, label='Vaccine')
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Intervention Period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.savefig('ws_all_measures.svg')  # Save the figure before showing it
plt.show()
