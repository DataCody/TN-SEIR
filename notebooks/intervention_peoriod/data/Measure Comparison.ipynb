# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Travel Network SEIR

# %%
fj_no_measure = pd.read_csv('fj/fj_no_measure.csv')
fp_no_measure = pd.read_csv('fp/fp_no_measure.csv')
wz_no_measure = pd.read_csv('ws/ws_no_measure.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_no_measure['Day'], fj_no_measure['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_no_measure['Day'], fp_no_measure['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(wz_no_measure['Day'], wz_no_measure['S'] / 1000, label='Samoa', marker='d', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_no_measure['Day'], fj_no_measure['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_no_measure['Day'], fp_no_measure['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(wz_no_measure['Day'], wz_no_measure['E'] / 1000, label='Samoa', marker='d', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_no_measure['Day'], fj_no_measure['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_no_measure['Day'], fp_no_measure['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(wz_no_measure['Day'], wz_no_measure['I'] / 1000, label='Samoa', marker='d', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_no_measure['Day'], fj_no_measure['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_no_measure['Day'], fp_no_measure['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(wz_no_measure['Day'], wz_no_measure['R'] / 1000, label='Samoa', marker='d', markevery=30)
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lockdown

# %%
fp_lockdownd = pd.read_csv('fp/fp_lockdownd_tahiti_borabora.csv')
fj_lockdownd = pd.read_csv('fj/fj_lockdownd_suva_nadi.csv')
ws_lockdownd = pd.read_csv('ws/ws_lockdownd_Faleata_Vaimauga_Sagaga.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_lockdownd['Day'], fj_lockdownd['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_lockdownd['Day'], fp_lockdownd['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_lockdownd['Day'], ws_lockdownd['S'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_lockdownd['Day'], fj_lockdownd['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_lockdownd['Day'], fp_lockdownd['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_lockdownd['Day'], ws_lockdownd['E'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_lockdownd['Day'], fj_lockdownd['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_lockdownd['Day'], fp_lockdownd['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_lockdownd['Day'], ws_lockdownd['I'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_lockdownd['Day'], fj_lockdownd['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_lockdownd['Day'], fp_lockdownd['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_lockdownd['Day'], ws_lockdownd['R'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Lockdown period')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Facemask

# %%
fp_mask = pd.read_csv('fp/fp_mask_surgical.csv')
fj_mask = pd.read_csv('fj/fj_mask_surgical.csv')
ws_mask = pd.read_csv('ws/ws_mask_surgical.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_mask['Day'], fj_mask['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_mask['Day'], fp_mask['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_mask['Day'], ws_mask['S'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Mask Usage')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_mask['Day'], fj_mask['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_mask['Day'], fp_mask['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_mask['Day'], ws_mask['E'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Mask Usage')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_mask['Day'], fj_mask['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_mask['Day'], fp_mask['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_mask['Day'], ws_mask['I'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Mask Usage')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_mask['Day'], fj_mask['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_mask['Day'], fp_mask['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_mask['Day'], ws_mask['R'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Mask Usage')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Social Distance

# %%
fp_social_1m = pd.read_csv('fp/fp_social_1m.csv')
fj_social_1m = pd.read_csv('fj/fj_social_1m.csv')
ws_social_1m = pd.read_csv('ws/ws_social_1m.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_social_1m['Day'], fj_social_1m['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_social_1m['Day'], fp_social_1m['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_social_1m['Day'], ws_social_1m['S'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Social Distancing')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_social_1m['Day'], fj_social_1m['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_social_1m['Day'], fp_social_1m['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_social_1m['Day'], ws_social_1m['E'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Social Distancing')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_social_1m['Day'], fj_social_1m['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_social_1m['Day'], fp_social_1m['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_social_1m['Day'], ws_social_1m['I'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Social Distancing')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_social_1m['Day'], fj_social_1m['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_social_1m['Day'], fp_social_1m['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_social_1m['Day'], ws_social_1m['R'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Social Distancing')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Remote Working

# %%
fp_wfh_50 = pd.read_csv('fp/fp_wfh_50.csv')
fj_wfh_50 = pd.read_csv('fj/fj_wfh_50.csv')
ws_wfh_50 = pd.read_csv('ws/ws_wfh_50.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_wfh_50['Day'], fj_wfh_50['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_wfh_50['Day'], fp_wfh_50['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_wfh_50['Day'], ws_wfh_50['S'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Remote Work')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_wfh_50['Day'], fj_wfh_50['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_wfh_50['Day'], fp_wfh_50['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_wfh_50['Day'], ws_wfh_50['E'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Remote Work')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_wfh_50['Day'], fj_wfh_50['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_wfh_50['Day'], fp_wfh_50['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_wfh_50['Day'], ws_wfh_50['I'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Remote Work')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_wfh_50['Day'], fj_wfh_50['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_wfh_50['Day'], fp_wfh_50['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_wfh_50['Day'], ws_wfh_50['R'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Remote Work')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Vaccine

# %%
fp_vaccine = pd.read_csv('fp/fp_vaccine_001rate.csv')
fj_vaccine = pd.read_csv('fj/fj_vaccine_001rate.csv')
ws_vaccine = pd.read_csv('ws/ws_vaccine_001rate.csv')

# %%
# Plot S
plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
plt.plot(fj_vaccine['Day'], fj_vaccine['S'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_vaccine['Day'], fp_vaccine['S'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_vaccine['Day'], ws_vaccine['S'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Vaccination')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Susceptible')
plt.legend(fontsize=6)

# Plot E
plt.subplot(2, 2, 2)
plt.plot(fj_vaccine['Day'], fj_vaccine['E'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_vaccine['Day'], fp_vaccine['E'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_vaccine['Day'], ws_vaccine['E'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Vaccination')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Exposed')
plt.legend(fontsize=6)

# Plot I
plt.subplot(2, 2, 3)
plt.plot(fj_vaccine['Day'], fj_vaccine['I'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_vaccine['Day'], fp_vaccine['I'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_vaccine['Day'], ws_vaccine['I'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Vaccination')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Infectious')
plt.legend(fontsize=6)

# Plot R
plt.subplot(2, 2, 4)
plt.plot(fj_vaccine['Day'], fj_vaccine['R'] / 1000, label='Fiji', marker='x', markevery=30)
plt.plot(fp_vaccine['Day'], fp_vaccine['R'] / 1000, label='French Polynesia', marker='o', markevery=30)
plt.plot(ws_vaccine['Day'], ws_vaccine['R'] / 1000, label='Samoa', marker='d', markevery=30)
# Highlight the intervention period
method_start = 10
method_end = 100
plt.axvspan(method_start, method_end, color='grey', alpha=0.5, label='Vaccination')
plt.xlabel('Day')
plt.ylabel('Population (thousand)')
plt.title('Recovered')
plt.legend(fontsize=6)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 10))

# Plot Fiji
plt.subplot(1, 3, 1)
plt.plot(fj_no_measure['Day'] / 7, fj_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='Lockdown')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)
plt.text(-0.1, 1.1, 'Lockdown', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot French Polynesia
plt.subplot(1, 3, 2)
plt.plot(fp_no_measure['Day'] / 7, fp_no_measure['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='Lockdown')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(1, 3, 3)
plt.plot(fj_tNet['Day'] / 7, fj_tNet['I'] / 1000, marker='x', markevery=30, label='No Intervention')
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='Lockdown')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)



# Plot S
plt.subplot(3, 4, 5)
plt.plot(fp_seir['Day'] / 7, fp_seir['S'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['S'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Susceptible (thousand)')
plt.legend(fontsize=8)
plt.text(-0.1, 1.1, 'French Polynesia', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot E
plt.subplot(3, 4, 6)
plt.plot(fp_seir['Day'] / 7, fp_seir['E'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['E'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Exposed (thousand)')

plt.legend(fontsize=8)

# Plot I
plt.subplot(3, 4, 7)
plt.plot(fp_seir['Day'] / 7, fp_seir['I'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['I'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')

plt.legend(fontsize=8)

# Plot R
plt.subplot(3, 4, 8)
plt.plot(fp_seir['Day'] / 7, fp_seir['R'] / 1000, marker='o', markevery=30)
plt.plot(fp_tNet['Day'] / 7, fp_tNet['R'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Recovered (thousand)')
plt.legend(fontsize=8)


# Plot S
plt.subplot(3, 4, 9)
plt.plot(ws_seir['Day'] / 7, ws_seir['S'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['S'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Susceptible (thousand)')
plt.legend(fontsize=8)
plt.text(-0.1, 1.1, 'Samoa', transform=plt.gca().transAxes, fontsize=14, fontweight='bold', va='top')

# Plot E
plt.subplot(3, 4, 10)
plt.plot(ws_seir['Day'] / 7, ws_seir['E'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['E'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Exposed (thousand)')

plt.legend(fontsize=8)

# Plot I
plt.subplot(3, 4, 11)
plt.plot(ws_seir['Day'] / 7, ws_seir['I'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['I'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')

plt.legend(fontsize=8)

# Plot R
plt.subplot(3, 4, 12)
plt.plot(ws_seir['Day'] / 7, ws_seir['R'] / 1000, marker='o', markevery=30)
plt.plot(ws_tNet['Day'] / 7, ws_tNet['R'] / 1000, marker='x', markevery=30)
plt.xlabel('EpiWeek')
plt.ylabel('Recovered (thousand)')
plt.legend(fontsize=8)

lines, labels = plt.subplot(3, 4, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='upper center', ncol=2, fontsize=10)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('seir_model_comparison.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Plot Fiji
plt.subplot(1, 3, 1)
plt.plot(fj_seir['Day'] / 7, fj_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fj_tNet['Day'] / 7, fj_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Fiji', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot French Polynesia
plt.subplot(1, 3, 2)
plt.plot(fp_seir['Day'] / 7, fp_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(fp_tNet['Day'] / 7, fp_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('French Polynesia', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

# Plot Samoa
plt.subplot(1, 3, 3)
plt.plot(ws_seir['Day'] / 7, ws_seir['I'] / 1000, marker='o', markevery=30, label='SEIR')
plt.plot(ws_tNet['Day'] / 7, ws_tNet['I'] / 1000, marker='x', markevery=30, label='TN-SEIR')
plt.xlabel('EpiWeek')
plt.ylabel('Infectious (thousand)')
plt.title('Samoa', fontsize=14, fontweight='bold')
plt.legend(fontsize=10).set_visible(False)

lines, labels = plt.subplot(1, 3, 1).get_legend_handles_labels()
plt.figlegend(lines, labels, loc='lower center', ncol=3, fontsize=10)
# Adjust layout and save figure
plt.tight_layout(rect=[0, 0.05, 1, 0.96])
plt.savefig('three_countries_seir_tn-seir.png', dpi=300)
plt.show()
